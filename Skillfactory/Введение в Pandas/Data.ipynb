# %%
import pandas as pd
countries = pd.Series(
    data = ['Англия', 'Канада', 'США', 'Россия', 'Страна 404', 'Беларусь', 'Казахстан', 'Пиндостан'],
    index = ['UK', 'CA', 'US', 'RU', 'UA', 'BY', 'KZ', 'PN'],
    name = 'countries'
)
countries.loc[['US', 'RU', 'UK']]
# Out:
# US       США
# RU    Россия
# UK    Англия
# Name: countries, dtype: object

# %%
countries_df = pd.DataFrame(
    data = [
        ['Англия', 56.29, 133396],
        ['Канада', 38.05, 9984670],
        ['США', 322.28, 9826630],
        ['Россия', 146.24, 17125191],
        ['Украина', 45.5, 603628],
        ['Беларусь', 9.5, 207600],
        ['Казахстан', 17.04, 2724902]
    ],
    columns= ['country', 'population', 'square'],
    index = ['UK', 'CA', 'US', 'RU', 'UA', 'BY', 'KZ']
)
display(countries_df)
# Out:
#       country  population    square
# UK     Англия       56.29    133396
# CA     Канада       38.05   9984670
# US        США      322.28   9826630
# RU     Россия      146.24  17125191
# UA    Украина       45.50    603628
# BY   Беларусь        9.50    207600
# KZ  Казахстан       17.04   2724902

# %%
countries_df = pd.DataFrame({
    'country': ['Англия', 'Канада', 'США', 'Россия', 'Украина', 'Беларусь', 'Казахстан'],
    'population': [56.29, 38.05, 322.28, 146.24, 45.5, 9.5, 17.04],
    'square': [133396, 9984670, 9826630, 17125191, 603628, 207600, 2724902]
})

countries_df.to_csv('data/countries.csv', index=False, sep=';')

# %%
countries_data = pd.read_csv('data/countries.csv', sep=';')
display(countries_data)
# Out:
#      country  population    square
# 0     Англия       56.29    133396
# 1     Канада       38.05   9984670
# 2        США      322.28   9826630
# 3     Россия      146.24  17125191
# 4    Украина       45.50    603628
# 5   Беларусь        9.50    207600
# 6  Казахстан       17.04   2724902

# %%
data = pd.read_csv('https://raw.githubusercontent.com/esabunor/MLWorkspace/master/melb_data.csv')
display(data)
# Out:
#        Unnamed: 0        Suburb           Address  Rooms Type      Price  \
# 0               1    Abbotsford      85 Turner St      2    h  1480000.0
# 1               2    Abbotsford   25 Bloomburg St      2    h  1035000.0
# 2               4    Abbotsford      5 Charles St      3    h  1465000.0
# 3               5    Abbotsford  40 Federation La      3    h   850000.0
# 4               6    Abbotsford       55a Park St      4    h  1600000.0
# ...           ...           ...               ...    ...  ...        ...
# 18391       23540  Williamstown   8/2 Thompson St      2    t   622500.0
# 18392       23541  Williamstown      96 Verdon St      4    h  2500000.0
# 18393       23544     Yallambie      17 Amaroo Wy      4    h  1100000.0
# 18394       23545    Yarraville        6 Agnes St      4    h  1285000.0
# 18395       23546    Yarraville     33 Freeman St      4    h  1050000.0
#
#       Method     SellerG        Date  Distance  ...  Bathroom  Car  Landsize  \
# ...

# %%
import pandas as pd
melb_data = pd.read_csv('data/melb_data.csv')
melb_data.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          13580 non-null  int64
#  1   Suburb         13580 non-null  object
#  2   Address        13580 non-null  object
#  3   Rooms          13580 non-null  int64
#  4   Type           13580 non-null  object
#  5   Price          13580 non-null  float64
#  6   Method         13580 non-null  object
#  7   SellerG        13580 non-null  object
#  8   Date           13580 non-null  object
#  9   Distance       13580 non-null  float64
#  10  Postcode       13580 non-null  int64
#  11  Bedroom        13580 non-null  float64
#  12  Bathroom       13580 non-null  float64
#  13  Car            13580 non-null  float64
#  14  Landsize       13580 non-null  float64
#  15  BuildingArea   13580 non-null  float64
#  16  YearBuilt      13580 non-null  float64
# ...

# %%
melb_data[(melb_data['Rooms'] == 3) & (melb_data['Price'] < 300000)].shape[0] #найдём число трёхкомнатных домов с ценой менее 300 тысяч
melb_data[((melb_data['Rooms'] == 3) | (melb_data['BuildingArea'] > 100)) & (melb_data['Price'] < 300000)].shape[0] #Немного «ослабим» условие: теперь нас будут интересовать 
                                                                #дома с ценой менее 300 тысяч, у которых либо число комнат равно 3 либо площадь домов более 100 квадратных метров
melb_data[melb_data['Type'] == 't']['Rooms'].max() #найдём максимальное количество комнат в таунхаусах
mean_price = melb_data['Price'].mean()
melb_data[melb_data['Price'] > mean_price]['BuildingArea'].median() #найдём медианную площадь здания у объектов, чья цена выше средней
melb_data [((melb_data['SellerG'] == 'Nelson') & (melb_data['Price'] > 3000000))] .shape[0]
melb_data [melb_data['BuildingArea'] == 0]['Price'].min()
melb_data[((melb_data['YearBuilt'] > 2015) | (melb_data['Rooms'] > 5)) & (melb_data['Price'] < 1000000)]['Price'].mean ()
melb_data[(melb_data['Price']<3e6) & (melb_data['Type']== 'h')]['Regionname'].mode()
# Out:
# 0    Northern Metropolitan
# Name: Regionname, dtype: object

# %%
student_data = pd.read_csv('data/students_performance.csv')
student_data.loc [(student_data['gender'] == 155)] 
#display (student_data [(student_data['lunch'] == 'standard')] ['math score'].mean())
#display (student_data [(student_data['lunch'] == 'free/reduced')] ['math score'].mean())
student_data.loc [(student_data['parental level of education'] == "bachelor's degree")].shape[0] / 1000
# Out:
# 0.118

# %%
median_score = student_data.loc [(student_data['race/ethnicity'] == 'group A')] ['writing score'].median()
mean_score = student_data [(student_data['race/ethnicity'] == "group C")] ['writing score'].mean ()
median_score - mean_score
# Out:
# -5.827586206896555

# %%
import pandas as pd
melb_data = pd.read_csv('data/melb_data_ps.csv', sep=',')
melb_df = melb_data.copy()
melb_df.head()
# Out:
#    index      Suburb           Address  Rooms Type      Price Method SellerG  \
# 0      0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1      1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2      2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3      3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4      4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  ...  Car  Landsize  BuildingArea  YearBuilt  \
# 0  3/12/2016       2.5  ...    1     202.0         126.0       1970
# 1  4/02/2016       2.5  ...    0     156.0          79.0       1900
# 2  4/03/2017       2.5  ...    0     134.0         150.0       1900
# 3  4/03/2017       2.5  ...    1      94.0         126.0       1970
# 4  4/06/2016       2.5  ...    2     120.0         142.0       2014
#
#    CouncilArea  Lattitude  Longtitude             Regionname  Propertycount  \
# ...

# %%
#melb_df = melb_df.drop(['index', 'Coordinates'], axis=1)
total_rooms = melb_df['Rooms'] + melb_df['Bedroom'] + melb_df['Bathroom']
melb_df['MeanRoomsSquare'] = melb_df['BuildingArea'] / total_rooms
diff_area = melb_df['BuildingArea'] - melb_df['Landsize'] #ещё один интересный признак — AreaRatio, коэффициент соотношения площади здания
sum_area = melb_df['BuildingArea'] + melb_df['Landsize']
melb_df['AreaRatio'] = diff_area/sum_area #Для этого разницу двух площадей поделим на их сумму
melb_df.describe(include=['object'])
melb_df['Date'] = pd.to_datetime(melb_df['Date'], dayfirst=True)
display(melb_df['Date'])
# Out:
# 0       2016-12-03
# 1       2016-02-04
# 2       2017-03-04
# 3       2017-03-04
# 4       2016-06-04
#            ...
# 13575   2017-08-26
# 13576   2017-08-26
# 13577   2017-08-26
# 13578   2017-08-26
# 13579   2017-08-26
# Name: Date, Length: 13580, dtype: datetime64[ns]

# %%
countries_df = pd.DataFrame({
    'country': ['Англия', 'Канада', 'США', 'Россия', 'Украина', 'Беларусь', 'Казахстан'],
    'population': [56.29, 38.05, 322.28, 146.24, 45.5, 9.5, 17.04],
    'square': [133396, 9984670, 9826630, 17125191, 603628, 207600, 2724902]
})
((countries_df['population']*1e6)/ (countries_df['square'])).mean()
# Out:
# 84.93080566562001

# %%
delta_days = melb_df['Date'] - pd.to_datetime('2016-01-01') 
melb_df['AgeBuilding'] = melb_df['Date'].dt.year - melb_df['YearBuilt']
display(melb_df['AgeBuilding'])
melb_df = melb_df.drop('YearBuilt', axis=1)
# Out:
# 0         46
# 1        116
# 2        117
# 3         47
# 4          2
#         ...
# 13575     36
# 13576     22
# 13577     20
# 13578     97
# 13579     97
# Name: AgeBuilding, Length: 13580, dtype: int64

# %%
melb_df['WeekdaySale'] = melb_df['Date'].dt.day_of_week
weekend_count.value_counts()[6] +weekend_count.value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [12], line 2
#       1 melb_df['WeekdaySale'] = melb_df['Date'].dt.day_of_week
# ----> 2 weekend_count.value_counts()[6] +weekend_count.value_counts()
#
# NameError: name 'weekend_count' is not defined

# %%
def get_street_type(address):
# Создаём список географических пометок exclude_list.
    exclude_list = ['N', 'S', 'W', 'E']
# Метод split() разбивает строку на слова по пробелу.
# В результате получаем список слов в строке и заносим его в переменную address_list.
    address_list = address.split(' ')
# Обрезаем список, оставляя в нём только последний элемент,
# потенциальный подтип улицы, и заносим в переменную street_type.
    street_type = address_list[-1]
# Делаем проверку на то, что полученный подтип является географической пометкой.
# Для этого проверяем его на наличие в списке exclude_list.
    if street_type in exclude_list:
# Если переменная street_type является географической пометкой,
# переопределяем её на второй элемент с конца списка address_list.
        street_type = address_list[-2]
# Возвращаем переменную street_type, в которой хранится подтип улицы.
    return street_type

# %%
street_types = melb_df['Address'].apply(get_street_type)
popular_stypes =street_types.value_counts().nlargest(10).index
#melb_df['StreetType'] = street_types.apply(lambda x: x if x in popular_stypes else 'other')
#melb_df = melb_df.drop('Address', axis=1)
melb_df['StreetType'] = street_types.apply(lambda x: 'Pde' if x == 'Parade' else x)# изменяю значение. Полное наименование заменяю на сокращение
melb_df['StreetType'].value_counts()
# Out:
# St           8012
# Rd           2825
# Ct            612
# Dr            447
# Av            321
# Gr            311
# Pde           226
# Pl            169
# Cr            152
# Cl            100
# La             67
# Bvd            53
# Tce            47
# Wy             40
# Avenue         40
# Cct            25
# Hwy            24
# Boulevard      13
# Sq             11
# Crescent        9
# Cir             7
# Strand          7
# Esplanade       6
# Grove           5
# Gdns            4
# Grn             4
# Fairway         4
# Mews            4
# Crossway        3
# Righi           3
# Victoria        2
# Ridge           2
# Crofts          2
# Esp             2
# Glade           1
# Gra             1
# Ave             1
# Woodland        1
# Outlook         1
# Hts             1
# Highway         1
# Athol           1
# Summit          1
# Grand           1
# Res             1
# Nook            1
# Eyrie           1
# Dell            1
# East            1
# Loop            1
# ...

# %% [markdown]
# ## Задание 4.2

# %%
def get_weekend(weekday): # Содал фукнцию, которая присваивает 1 если выходной и 0 если остальные
    return 1 if weekday == 5 or weekday == 6 else 0
melb_df ['Weekend'] = melb_df['WeekdaySale'].apply (get_weekend)
price_week_end = melb_df [(melb_df ['Weekend'] == 1)] ['Price'].mean()
price_week_end
# Out:
# 1081198.6406956792

# %%
best_seller = melb_df ['SellerG'].value_counts().nlargest(49).index
melb_df['SellerG'] = melb_df['SellerG'].apply(lambda x: x if x in best_seller else 'other')
(melb_df [(melb_df['SellerG'] == 'Nelson')]['Price'].min()) / (melb_df [(melb_df['SellerG'] == 'other')]['Price'].min())
# Out:
# 1.297709923664122

# %%
# создаём пустой список
unique_list = []
# пробегаемся по именам столбцов в таблице
for col in melb_df.columns:
    # создаём кортеж (имя столбца, число уникальных значений)
    item = (col, melb_df[col].nunique(),melb_df[col].dtypes) 
    # добавляем кортеж в список
    unique_list.append(item) 
# создаём вспомогательную таблицу и сортируем её
unique_counts = pd.DataFrame(
    unique_list,
    columns=['Column_Name', 'Num_Unique', 'Type']
).sort_values(by='Num_Unique',  ignore_index=True)
# выводим её на экран
display(unique_counts)
# Out:
#         Column_Name  Num_Unique            Type
# 0           Weekend           2           int64
# 1              Type           3          object
# 2       WeekdaySale           5           int64
# 3            Method           5          object
# 4        Regionname           8          object
# 5             Rooms           9           int64
# 6          Bathroom           9           int64
# 7               Car          11           int64
# 8           Bedroom          12           int64
# 9       CouncilArea          33          object
# 10          SellerG          49          object
# 11       StreetType          55          object
# 12             Date          58  datetime64[ns]
# 13      AgeBuilding         152           int64
# 14         Postcode         198           int64
# 15         Distance         202         float64
# 16    Propertycount         311           int64
# 17           Suburb         314          object
# 18     BuildingArea         602         float64
# ...

# %% [markdown]
# # Выполнение заданий 3.4-3.5

# %%
ufo_data = pd.read_csv('data/UFO.csv', sep=',')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18241 entries, 0 to 18240
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   City             18216 non-null  object
#  1   Colors Reported  2882 non-null   object
#  2   Shape Reported   15597 non-null  object
#  3   State            18241 non-null  object
#  4   Time             18241 non-null  object
# dtypes: object(5)
# memory usage: 712.7+ KB
# None

# %%
ufo_data ['Time'] = pd.to_datetime(ufo_data ['Time'], dayfirst=True)
Year = ufo_data ['Time'].dt.year
ufo_data.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18241 entries, 0 to 18240
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   City             18216 non-null  object
#  1   Colors Reported  2882 non-null   object
#  2   Shape Reported   15597 non-null  object
#  3   State            18241 non-null  object
#  4   Time             18241 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), object(4)
# memory usage: 712.7+ KB

# %%
Nevada_data = ufo_data [(ufo_data['State'] == 'NV')]
nevada_days = Nevada_data ['Time'].dt.date
nevada_days.diff(periods=1).dt.days.mean()
# Out:
# 68.72084805653711

# %%
melb_df['Address'].nunique()
# Out:
# 13378

# %%
# создаём пустой список
unique_list = []
# пробегаемся по именам столбцов в таблице
for col in melb_df.columns:
    # создаём кортеж (имя столбца, число уникальных значений)
    item = (col, melb_df[col].nunique(),melb_df[col].dtypes) 
    # добавляем кортеж в список
    unique_list.append(item) 
# создаём вспомогательную таблицу и сортируем её
unique_counts = pd.DataFrame(
    unique_list,
    columns=['Column_Name', 'Num_Unique', 'Type']
).sort_values(by='Num_Unique',  ignore_index=True)
# выводим её на экран
display(melb_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 27 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   index            13580 non-null  int64
#  1   Suburb           13580 non-null  object
#  2   Address          13580 non-null  object
#  3   Rooms            13580 non-null  int64
#  4   Type             13580 non-null  object
#  5   Price            13580 non-null  float64
#  6   Method           13580 non-null  object
#  7   SellerG          13580 non-null  object
#  8   Date             13580 non-null  datetime64[ns]
#  9   Distance         13580 non-null  float64
#  10  Postcode         13580 non-null  int64
#  11  Bedroom          13580 non-null  int64
#  12  Bathroom         13580 non-null  int64
#  13  Car              13580 non-null  int64
#  14  Landsize         13580 non-null  float64
#  15  BuildingArea     13580 non-null  float64
# ...

# %%
cols_to_exclude = ['Date', 'Rooms', 'Bedroom', 'Bathroom', 'Car'] # список столбцов, которые мы не берём во внимание
max_unique_count = 150 # задаём максимальное число уникальных категорий
for col in melb_df.columns: # цикл по именам столбцов
    if melb_df[col].nunique() < max_unique_count and col not in cols_to_exclude: # проверяем условие
        melb_df[col] = melb_df[col].astype('category') # преобразуем тип столбца
display(melb_df['Regionname'].cat.codes)
# Out:
# 0        2
# 1        2
# 2        2
# 3        2
# 4        2
#         ..
# 13575    4
# 13576    6
# 13577    6
# 13578    6
# 13579    6
# Length: 13580, dtype: int8

# %%
melb_df['Type'] = melb_df['Type'].cat.rename_categories({
    'u': 'unit',
    't': 'townhouse',
    'h': 'house'
})
new_houses_types = pd.Series(['unit', 'house', 'flat', 'flat', 'house'])
new_houses_types = new_houses_types.astype(melb_df['Type'].dtype)
melb_df['Type'] = melb_df['Type'].cat.add_categories('flat')
new_houses_types = pd.Series(['unit', 'house', 'flat', 'flat', 'house'])
new_houses_types = new_houses_types.astype(melb_df['Type'].dtype)
display(new_houses_types)
# Out:
# 0     unit
# 1    house
# 2     flat
# 3     flat
# 4    house
# dtype: category
# Categories (4, object): ['house', 'townhouse', 'unit', 'flat']

# %% [markdown]
# ## Итоговые задания к модулю

# %%
import pandas as pd
Citi_Bike = pd.read_csv('data/citibike-tripdata.csv', sep=',')
Citi_Bike ['usertype'].value_counts()
# Out:
# Subscriber    232202
# Customer       67798
# Name: usertype, dtype: int64

# %%
mode_usertype = Citi_Bike['usertype'].mode()[0]
count_mode_user = Citi_Bike[Citi_Bike['usertype'] == mode_usertype].shape [0]
print(round(count_mode_user / Citi_Bike.shape[0], 2))
# Out:
# 0.77

# %%
mode_gender = Citi_Bike['gender'].mode()[0]
count_mode_user = Citi_Bike[Citi_Bike['gender'] == mode_gender].shape [0]# подсчитываем количество самых частых гендеров, выводим одним числом
count_mode_user
# Out:
# 183582

# %%
start = Citi_Bike['start station name'].nunique()
finish = Citi_Bike['end station name'].nunique()
start == finish
# Out:
# False

# %%
Citi_Bike['birth year'].max()
finish = Citi_Bike['start station name'].value_counts()
finish
Citi_Bike_Data = Citi_Bike.copy()

# %%
#Citi_Bike_Data = Citi_Bike_Data.drop('end station id', axis=1)
Citi_Bike_Data['age'] = 2018 - Citi_Bike_Data['birth year'] # добавляем столбец age и заполняем его возрастом по формуле 2018 - год рождения
Citi_Bike_Data.drop(['birth year'], axis=1, inplace=True) # удаляем столбец года рождения
print(Citi_Bike_Data[Citi_Bike_Data['age'] > 60].shape[0])
# Out:
# 11837

# %%
Citi_Bike_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300000 entries, 0 to 299999
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   starttime                300000 non-null  object
#  1   stoptime                 300000 non-null  object
#  2   start station id         299831 non-null  float64
#  3   start station name       299831 non-null  object
#  4   start station latitude   300000 non-null  float64
#  5   start station longitude  300000 non-null  float64
#  6   end station id           299831 non-null  float64
#  7   end station name         299831 non-null  object
#  8   end station latitude     300000 non-null  float64
#  9   end station longitude    300000 non-null  float64
#  10  bikeid                   300000 non-null  int64
#  11  usertype                 300000 non-null  object
#  12  gender                   300000 non-null  int64
# ...

# %%
Citi_Bike_Data['starttime'] = pd.to_datetime(Citi_Bike_Data['starttime'], dayfirst=True)
#Citi_Bike_Data['starttime'].head(50)

# %%
time = Citi_Bike_Data['stoptime'] - Citi_Bike_Data['starttime']
time [3]
# Out:
# Timedelta('0 days 00:07:16.837000')

# %%
weekday = Citi_Bike_Data['starttime'].dt.dayofweek
Citi_Bike_Data['weekend'] = weekday.apply(lambda x: 1 if x ==5 or x == 6 else 0)
Citi_Bike_Data['weekend'].sum()
# Out:
# 115135

# %%
def get_time_of_day(time):
    if 0 <= time <= 6:
        return 'night'
    elif 6 < time <= 12:
        return 'morning'
    elif 12 < time <= 18:
        return 'day'
    elif 18 < time <= 23:
        return 'evening'
    else:
        return 'else'
Citi_Bike_Data['time_of_day'] = Citi_Bike_Data['starttime'].dt.hour.apply(get_time_of_day)
a = Citi_Bike_Data[Citi_Bike_Data['time_of_day'] == 'day'].shape[0]
b = Citi_Bike_Data[Citi_Bike_Data['time_of_day'] == 'night'].shape[0]
print(round(a / b))
# Out:
# 9

# %% [markdown]
# # Python 12 Начало модуля

# %%
#import pandas as pd
#melb_data_fe = pd.read_csv('data/melb_data_fe.csv')# подгрузил исковерканную базу Мельбурна для дальшейшей экзекуции
#melb_df = melb_data_fe.copy()
melb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 26 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Suburb           13580 non-null  object
#  1   Rooms            13580 non-null  int64
#  2   Type             13580 non-null  object
#  3   Price            13580 non-null  float64
#  4   Method           13580 non-null  object
#  5   SellerG          13580 non-null  object
#  6   Date             13580 non-null  datetime64[ns]
#  7   Distance         13580 non-null  float64
#  8   Postcode         13580 non-null  int64
#  9   Bedroom          13580 non-null  int64
#  10  Bathroom         13580 non-null  int64
#  11  Car              13580 non-null  int64
#  12  Landsize         13580 non-null  float64
#  13  BuildingArea     13580 non-null  float64
#  14  CouncilArea      12211 non-null  object
#  15  Lattitude        13580 non-null  float64
# ...

# %%
melb_df ['Date'] = pd.to_datetime (melb_df ['Date'], dayfirst=True)
answer = melb_df ['Date'].dt.quarter.value_counts()
answer
# Out:
# 3    4873
# 2    4359
# 4    2329
# 1    2019
# Name: Date, dtype: int64

# %%
cols_to_exclude = ['Date', 'Rooms', 'Bedroom', 'Bathroom', 'Car'] # список столбцов, которые мы не берём во внимание
max_unique_count = 150 # задаём максимальное число уникальных категорий
for col in melb_df.columns: # цикл по именам столбцов
    if melb_df[col].nunique() < max_unique_count and col not in cols_to_exclude: # проверяем условие
        melb_df[col] = melb_df[col].astype('category') # преобразуем тип столбца
melb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 26 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Suburb           13580 non-null  category
#  1   Rooms            13580 non-null  int64
#  2   Type             13580 non-null  category
#  3   Price            13580 non-null  float64
#  4   Method           13580 non-null  category
#  5   SellerG          13580 non-null  category
#  6   Date             13580 non-null  datetime64[ns]
#  7   Distance         13580 non-null  float64
#  8   Postcode         13580 non-null  int64
#  9   Bedroom          13580 non-null  int64
#  10  Bathroom         13580 non-null  int64
#  11  Car              13580 non-null  int64
#  12  Landsize         13580 non-null  float64
#  13  BuildingArea     13580 non-null  float64
#  14  CouncilArea      12211 non-null  category
#  15  Lattitude        13580 non-null  float64
# ...

# %%
melb_df.sort_values(by='Price').head(10)
# Out:
#                Suburb  Rooms   Type     Price Method        SellerG  \
# 2652        Footscray      1   unit   85000.0     PI        Burnham
# 1805            other      4  house  131000.0     PI          other
# 7303           Albion      1   unit  145000.0     PI         Biggin
# 1927           Coburg      4  house  145000.0     PI         Jellis
# 7940         Hawthorn      1   unit  160000.0     VB            HAR
# 12666       Brunswick      1   unit  170000.0     VB         Nelson
# 8811        Footscray      1   unit  170000.0     PI        Burnham
# 8504   West Footscray      1   unit  185000.0     PI            Jas
# 7293           Albion      1   unit  185000.0      S  hockingstuart
# 7305           Albion      2   unit  190000.0     SP        Burnham
#
#             Date  Distance  Postcode  Bedroom  ...  Longtitude  \
# 2652  2016-03-09       6.4      3011        1  ...   144.89000
# 1805  2017-02-25       8.9      3162        4  ...   145.02420
# ...

# %%
melb_df.sort_values(by='Date', ascending=False)
# Out:
#              Suburb  Rooms   Type      Price Method    SellerG       Date  \
# 11144     Northcote      4  house  1955000.0     SP    McGrath 2017-12-08
# 11217  Surrey Hills      3  house  1775000.0     PI     Jellis 2017-12-08
# 11206      St Kilda      4  house  1600000.0     VB       Gary 2017-12-08
# 11207    Strathmore      7  house  2000000.0     SP     Nelson 2017-12-08
# 11208    Strathmore      4  house  1610000.0      S      other 2017-12-08
# ...             ...    ...    ...        ...    ...        ...        ...
# 1555     Camberwell      4  house  2650000.0      S     Jellis 2016-03-09
# 4510       Oak Park      3  house   892000.0      S     Nelson 2016-03-09
# 4388      Northcote      3  house  1200000.0      S     Nelson 2016-03-09
# 6184   Surrey Hills      3  house  1205000.0      S  Fletchers 2016-01-28
# 6183   Surrey Hills      2   unit   813000.0      S  Fletchers 2016-01-28
#
#        Distance  Postcode  Bedroom  ...  Longtitude             Regionname  \
# ...

# %%
melb_df.sort_values(by=['Distance', 'Price']).loc[::10, ['Distance', 'Price']]
# Out:
#        Distance      Price
# 11428       0.0   387000.0
# 10512       0.7   600000.0
# 5727        1.2   485000.0
# 8671        1.2   595000.0
# 5736        1.2   740000.0
# ...         ...        ...
# 12011      38.0   680000.0
# 10673      38.0   810000.0
# 13429      38.0  1155000.0
# 11102      41.0   650000.0
# 12728      45.9   650000.0
#
# [1358 rows x 2 columns]

# %%
mask1 = melb_df['AreaRatio'] < -0.8 #    Найдём информацию о таунхаусах (Type), проданных компанией (SellerG) McGrath, у которых коэффициент соотношения площадей
mask2 = melb_df['Type'] == 'townhouse'#  здания и участка (AreaRatio) меньше -0.8. Результат отсортируем по дате продажи (Date) в порядке возрастания, а после проведём
mask3 = melb_df['SellerG'] == 'McGrath'# сортировку по убыванию коэффициента соотношения площадей. Также обновим старые индексы на новые, установив параметр
melb_df[mask1 & mask2 & mask3].sort_values(# ignore_index на True. Для наглядности результата выберем из таблицы только столбцы Data и AreaRatio:
    by=['Date', 'AreaRatio'],#
    ascending=[True, False],
    ignore_index=True
).loc[:, ['Date', 'AreaRatio']]
# Out:
#         Date  AreaRatio
# 0 2016-07-26  -0.974922
# 1 2016-09-24  -0.971831
# 2 2016-11-27  -0.953608
# 3 2016-12-11  -0.945946
# 4 2017-08-04  -0.947368
# 5 2017-08-04  -0.970874

# %%
melb_df.sort_values(by='Date', ascending=False, ignore_index=True)
melb_df['BuildingArea'][1558]
# Out:
# 126.0

# %%
mask1 = melb_df['Type'] == 'townhouse'
mask2 = melb_df['Rooms'] > 2
int(melb_df[mask1&mask2].sort_values(
    by=['Rooms', 'MeanRoomsSquare'],
    ascending=[True, False],
    ignore_index=True
).loc[18, 'Price'])
# Out:
# 1300000

# %%
#melb_df.groupby(by='Type').mean()
#melb_df.groupby('Type')['Price'].mean()
#melb_df.groupby('Regionname')['Distance'].min().sort_values(ascending=False)
#melb_df.groupby('MonthSale')['Price'].agg(
#    ['count', 'mean', 'max']
#).sort_values(by='count', ascending=False)
melb_df.groupby('Regionname')['SellerG'].agg(
    		['nunique', set]
)
# Out:
#                             nunique  \
# Regionname
# Eastern Metropolitan             26
# Eastern Victoria                 11
# Northern Metropolitan            40
# Northern Victoria                11
# South-Eastern Metropolitan       25
# Southern Metropolitan            38
# Western Metropolitan             34
# Western Victoria                  6
#
#                                                                           set
# Regionname
# Eastern Metropolitan        {HAR, Ray, C21, Jellis, Barry, Fletchers, Wood...
# Eastern Victoria            {Barry, Fletchers, Ray, other, O'Brien, hockin...
# Northern Metropolitan       {Collins, Greg, Raine, Burnham, Village, HAR, ...
# Northern Victoria           {YPA, Raine, Barry, HAR, other, Ray, hockingst...
# South-Eastern Metropolitan  {Greg, HAR, Ray, Hodges, Jellis, C21, Barry, F...
# Southern Metropolitan       {Collins, Greg, Raine, HAR, Ray, Hodges, Jelli...
# ...

# %% [markdown]
# ## Задание 3.1 и т.д.

# %%
#melb_df.groupby ('Rooms') ['Price'].mean().sort_values(ascending=False)
#melb_df.groupby ('Regionname') ['Lattitude'].std()
mask1 = melb_df ['Date'] < '2017-09-01' 
mask2 = melb_df ['Date'] > '2017-05-01'
melb_df[mask1 & mask2].groupby ('SellerG') ['Price'].sum ().sort_values(ascending=False)
# Out:
# SellerG
# Jellis           414121833.0
# Nelson           379767500.0
# other            365038432.0
# Barry            296723050.0
# hockingstuart    282834310.0
# Marshall         253957888.0
# Ray              249572986.0
# Buxton           219104000.0
# Biggin           110429500.0
# Fletchers        108847700.0
# Noel              88129800.0
# Woodards          85977500.0
# Greg              85621000.0
# McGrath           78386500.0
# Harcourts         68720250.0
# Jas               59281600.0
# Brad              55955000.0
# RT                50498000.0
# Kay               48569500.0
# Miles             47582000.0
# YPA               46354350.0
# Hodges            43231000.0
# Gary              39138400.0
# Sweeney           36882750.0
# Stockdale         35409800.0
# Raine             30687700.0
# RW                29261000.0
# Village           26473000.0
# HAR               25568000.0
# O'Brien           23855508.0
# Purplebricks      23401000.0
# ...

# %% [markdown]
# ## Сводные таблицы

# %%
melb_df.groupby(['Rooms', 'Type'])['Price'].mean()
# Out:
# Rooms  Type
# 1      house        8.668655e+05
#        townhouse    5.927045e+05
#        unit         3.899289e+05
# 2      house        1.017238e+06
#        townhouse    7.101585e+05
#        unit         6.104905e+05
# 3      house        1.109233e+06
#        townhouse    9.847087e+05
#        unit         8.505963e+05
# 4      house        1.462283e+06
#        townhouse    1.217092e+06
#        unit         1.037476e+06
# 5      house        1.877327e+06
#        townhouse    1.035000e+06
#        unit                  NaN
# 6      house        1.869508e+06
#        townhouse             NaN
#        unit         5.200000e+05
# 7      house        1.920700e+06
#        townhouse             NaN
#        unit                  NaN
# 8      house        1.510286e+06
#        townhouse             NaN
#        unit         2.250000e+06
# 10     house        9.000000e+05
#        townhouse             NaN
#        unit                  NaN
# Name: Price, dtype: float64

# %%
melb_df.groupby(['Rooms', 'Type'])['Price'].mean().unstack()
# Out:
# Type          house     townhouse          unit
# Rooms
# 1      8.668655e+05  5.927045e+05  3.899289e+05
# 2      1.017238e+06  7.101585e+05  6.104905e+05
# 3      1.109233e+06  9.847087e+05  8.505963e+05
# 4      1.462283e+06  1.217092e+06  1.037476e+06
# 5      1.877327e+06  1.035000e+06           NaN
# 6      1.869508e+06           NaN  5.200000e+05
# 7      1.920700e+06           NaN           NaN
# 8      1.510286e+06           NaN  2.250000e+06
# 10     9.000000e+05           NaN           NaN

# %%
melb_df.pivot_table(
    values='Price',
    index='Rooms',
    columns='Type',
    fill_value=0
).round()
# Out:
# Type       house  townhouse       unit
# Rooms
# 1       866866.0   592705.0   389929.0
# 2      1017238.0   710158.0   610491.0
# 3      1109233.0   984709.0   850596.0
# 4      1462283.0  1217092.0  1037476.0
# 5      1877327.0  1035000.0        0.0
# 6      1869508.0        0.0   520000.0
# 7      1920700.0        0.0        0.0
# 8      1510286.0        0.0  2250000.0
# 10      900000.0        0.0        0.0

# %%
melb_df.pivot_table(
    values='Price',
    index='Regionname',
    columns='Weekend',
    aggfunc='count'
)
# Out:
# Weekend                        0     1
# Regionname
# Eastern Metropolitan         447  1024
# Eastern Victoria              13    40
# Northern Metropolitan       1258  2632
# Northern Victoria             11    30
# South-Eastern Metropolitan   123   327
# Southern Metropolitan       1534  3161
# Western Metropolitan         960  1988
# Western Victoria               8    24

# %%
melb_df.pivot_table(
    values='Landsize',
    index='Regionname',
    columns='Type',
    aggfunc=['median', 'mean'],
    fill_value=0
)
# Out:
#                            median                        mean              \
# Type                        house townhouse unit        house   townhouse
# Regionname
# Eastern Metropolitan        674.0     233.5  203   717.422847  269.440678
# Eastern Victoria            843.0       0.0  230  3108.960000    0.000000
# Northern Metropolitan       459.5     134.0    0   619.249092  317.325733
# Northern Victoria           724.0       0.0    0  3355.463415    0.000000
# South-Eastern Metropolitan  630.5     240.0  199   664.306701  212.160000
# Southern Metropolitan       586.0     246.0    0   569.643881  278.858824
# Western Metropolitan        531.0     198.0   62   507.883406  244.560669
# Western Victoria            599.5       0.0    0   655.500000    0.000000
#
#
# Type                              unit
# Regionname
# Eastern Metropolitan        330.444444
# Eastern Victoria            295.333333
# Northern Metropolitan       495.026538
# Northern Victoria             0.000000
# ...

# %%
melb_df.pivot_table(
    values='Price',
    index=['Method','Type'],
    columns='Regionname',
    aggfunc='median',
    fill_value=0
)
# Out:
# Regionname        Eastern Metropolitan  Eastern Victoria  \
# Method Type
# PI     house                   1244000            780000
#        townhouse                760000                 0
#        unit                     650000                 0
# S      house                   1127000            675000
#        townhouse                828000                 0
#        unit                     645750            492000
# SA     house                    932500            950000
#        townhouse                807500                 0
#        unit                          0                 0
# SP     house                   1050000            672500
#        townhouse                910000                 0
#        unit                     515000            400000
# VB     house                   1100000            712500
#        townhouse                892500                 0
#        unit                     500000                 0
#
# ...

# %% [markdown]
# ## Задание 4.2

# %%
melb_df.pivot_table (
    values = "BuildingArea",
    index = 'Type', 
    columns='Rooms',
    aggfunc='median',
    fill_value=0
)
# Out:
# Rooms         1    2    3      4    5    6      7    8    10
# Type
# house      126.0  126  126  141.0  177  126  216.5  126  126
# townhouse   88.0  114  126  159.5  152    0    0.0    0    0
# unit        69.5  110  126  126.0    0  171    0.0  126    0

# %% [markdown]
# ##Задание 4.3

# %%
pivot = melb_df.pivot_table (
    values = "Price",
    index = 'SellerG', 
    columns='Type',
    aggfunc='median',
    fill_value=0
)
pivot
# Out:
# Type             house  townhouse    unit
# SellerG
# Alexkarbon     1036250     935000  560000
# Barry           830000     727500  502000
# Bells           692500     430500  457500
# Biggin         1151750     675000  548000
# Brad            875000     700000  465000
# Buckingham      830000     820000  553000
# Burnham         922500          0  305000
# Buxton         1323750    1030000  670000
# C21             836500     768750  625500
# Cayzer         1505000    1450000  707500
# Chisholm       1520000     950000  640000
# Collins        1566500     930000  592000
# Douglas         684000     500000  494500
# Eview           760000     597500  602000
# Fletchers      1390000    1238000  653000
# Gary           1370000     993500  550000
# Greg           1330000     900000  547500
# HAR             695000          0  518000
# Harcourts       740000     653750  500000
# Hodges         1500000    1105000  605500
# Jas             935000     699000  455000
# ...

# %%
melb_df ['Date'].head ()
# Out:
# 0   2016-03-12
# 1   2016-04-02
# 2   2017-04-03
# 3   2017-04-03
# 4   2016-04-06
# Name: Date, dtype: datetime64[ns]

# %% [markdown]
# ## Новый дата сет из фильмов

# %%
#import pandas as pd
#movies_df = pd.read_csv('data/movies.csv')# подгрузил базу фильмов
#rating1_df = pd.read_csv('data/ratings1.csv')
#rating2_df = pd.read_csv('data/ratings2.csv')
dates = pd.read_csv('data/dates.csv')
dates ['date'] = pd.to_datetime (dates_df ['date'], dayfirst=False)
#dates_df['year'] = dates_df['date'].dt.year
#dates_df['year'].value_counts()

# %%
ratings = pd.concat ([rating1_df, rating2_df],ignore_index=True)
ratings
# Out:
#         userId  movieId  rating
# 0            1        1     4.0
# 1            1        3     4.0
# 2            1        6     4.0
# 3            1       47     5.0
# 4            1       50     5.0
# ...        ...      ...     ...
# 100832     610   166534     4.0
# 100833     610   168248     5.0
# 100834     610   168250     5.0
# 100835     610   168252     5.0
# 100836     610   170875     3.0
#
# [100837 rows x 3 columns]

# %%
print('Число строк в таблице ratings: ', ratings.shape[0])
print('Число строк в таблице dates: ', dates.shape[0])
print(ratings.shape[0] == dates.shape[0])
# Out:
# Число строк в таблице ratings:  100837
# Число строк в таблице dates:  100836
# False

# %%
display(rating1_df.tail(1))
display(rating2_df.head(1))
# Out:
#        userId  movieId  rating
# 40000     274     5621     2.0
#    userId  movieId  rating
# 0     274     5621     2.0

# %%
ratings = ratings.drop_duplicates(ignore_index=True)
print('Число строк в таблице ratings: ', ratings.shape[0])
# Out:
# Число строк в таблице ratings:  100836

# %%
ratings_dates = pd.concat([ratings, dates], axis=1)
display(ratings_dates.tail(7))
# Out:
#         userId  movieId  rating                date
# 100829     610   164179     5.0 2017-05-03 21:07:11
# 100830     610   166528     4.0 2017-05-04 06:29:25
# 100831     610   166534     4.0 2017-05-03 21:53:22
# 100832     610   168248     5.0 2017-05-03 22:21:31
# 100833     610   168250     5.0 2017-05-08 19:50:47
# 100834     610   168252     5.0 2017-05-03 21:19:12
# 100835     610   170875     3.0 2017-05-03 21:20:15

# %% [markdown]
# ## Задание 6.2
# В ваше распоряжение предоставлена директория users. В данной директории содержатся csv-файлы, в каждом из которых хранится информация об идентификаторах пользователей (user_id) и ссылки на их фотографии (photo_url). Файлов в директории может быть сколько угодно.
#
# Вам необходимо написать функцию concat_user_files(path), параметром которой является path — путь до директории. Функция должна объединить информацию из предоставленных вам файлов в один DataFrame и вернуть его.
#
# Список названий всех файлов, находящихся в директории, вы можете получить с помощью функции os.listdir(path) из модуля os. Отсортируйте полученный список, прежде чем производить объединение файлов.
#
# Обратите внимание, что метод os.listdir() возвращает только названия файлов в указанной директории, а при чтении файла необходимо указывать полный путь до него.
#
# Не забудьте обновить индексы результирующей таблицы после объединения.
#
# Примечание. Учтите, что на тестовом наборе файлов в результате объединения могут возникнуть дубликаты, от которых необходимо будет избавиться.

# %%
def concat_users_files(path):
    data = pd.DataFrame()
    file_names = os.listdir(path)
    file_names.sort()
    for file in file_names:
        tmp_data = pd.read_csv(path + '/' + file)
        data = pd.concat([data, tmp_data], axis=0, ignore_index=True)
    data = data.drop_duplicates()
    return data

# %%
joined_false = ratings_dates.join(
    movies_df,
    rsuffix='_right',
    how='left'
)
display(joined_false)
# Out:
#         userId  movieId  rating                date  movieId_right  \
# 0            1        1     4.0 2000-07-30 18:45:03            1.0
# 1            1        3     4.0 2000-07-30 18:20:47            2.0
# 2            1        6     4.0 2000-07-30 18:37:04            3.0
# 3            1       47     5.0 2000-07-30 19:03:35            4.0
# 4            1       50     5.0 2000-07-30 18:48:51            5.0
# ...        ...      ...     ...                 ...            ...
# 100831     610   166534     4.0 2017-05-03 21:53:22            NaN
# 100832     610   168248     5.0 2017-05-03 22:21:31            NaN
# 100833     610   168250     5.0 2017-05-08 19:50:47            NaN
# 100834     610   168252     5.0 2017-05-03 21:19:12            NaN
# 100835     610   170875     3.0 2017-05-03 21:20:15            NaN
#
#                                      title  \
# 0                         Toy Story (1995)
# 1                           Jumanji (1995)
# ...

# %%
joined = ratings_dates.join(
    movies_df.set_index('movieId'),
    on='movieId',
    how='left'
)
display(joined.head())
# Out:
#    userId  movieId  rating                date                        title  \
# 0       1        1     4.0 2000-07-30 18:45:03             Toy Story (1995)
# 1       1        3     4.0 2000-07-30 18:20:47      Grumpier Old Men (1995)
# 2       1        6     4.0 2000-07-30 18:37:04                  Heat (1995)
# 3       1       47     5.0 2000-07-30 19:03:35  Seven (a.k.a. Se7en) (1995)
# 4       1       50     5.0 2000-07-30 18:48:51   Usual Suspects, The (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                               Comedy|Romance
# 2                        Action|Crime|Thriller
# 3                             Mystery|Thriller
# 4                       Crime|Mystery|Thriller

# %%
merged = ratings_dates.merge(
    movies_df,
    on='movieId',
    how='left'
)
display(merged.head())
# Out:
#    userId  movieId  rating                date                        title  \
# 0       1        1     4.0 2000-07-30 18:45:03             Toy Story (1995)
# 1       1        3     4.0 2000-07-30 18:20:47      Grumpier Old Men (1995)
# 2       1        6     4.0 2000-07-30 18:37:04                  Heat (1995)
# 3       1       47     5.0 2000-07-30 19:03:35  Seven (a.k.a. Se7en) (1995)
# 4       1       50     5.0 2000-07-30 18:48:51   Usual Suspects, The (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                               Comedy|Romance
# 2                        Action|Crime|Thriller
# 3                             Mystery|Thriller
# 4                       Crime|Mystery|Thriller

# %%
print('Число строк в таблице ratings_dates: ', ratings_dates.shape[0])
print('Число строк в таблице merged: ', merged.shape[0])
print(ratings_dates.shape[0] == merged.shape[0])
# Out:
# Число строк в таблице ratings_dates:  100836
# Число строк в таблице merged:  100836
# True

# %%
a = pd.DataFrame({'A': ['a', 'b', 'c'], 'B': [103, 214, 124], 'C': [1, 4, 2]})
b = pd.DataFrame({'V': ['d', 'b', 'c'], 'U': [1393.7, 9382.2, 1904.5], 'C': [1, 3, 2]})
display (a.merge(b, how='right', on='C'))
# Out:
#      A      B  C  V       U
# 0    a  103.0  1  d  1393.7
# 1  NaN    NaN  3  b  9382.2
# 2    c  124.0  2  c  1904.5

# %% [markdown]
# ## Задание 7.5
# на объединение фреймов

# %%
items_df = pd.DataFrame({
    'item_id': [417283, 849734, 132223, 573943, 19475, 3294095, 382043, 302948, 100132, 312394], 
    'vendor': ['Samsung', 'LG', 'Apple', 'Apple', 'LG', 'Apple', 'Samsung', 'Samsung', 'LG', 'ZTE'],
    'stock_count': [54, 33, 122, 18, 102, 43, 77, 143, 60, 19]
})
purchase_df = pd.DataFrame({
    'purchase_id': [101, 101, 101, 112, 121, 145, 145, 145, 145, 221],
    'item_id': [417283, 849734, 132223, 573943, 19475, 3294095, 382043, 302948, 103845, 100132], 
    'price': [13900, 5330, 38200, 49990, 9890, 33000, 67500, 34500, 89900, 11400]
})
display(items_df, purchase_df)
# Out:
#    item_id   vendor  stock_count
# 0   417283  Samsung           54
# 1   849734       LG           33
# 2   132223    Apple          122
# 3   573943    Apple           18
# 4    19475       LG          102
# 5  3294095    Apple           43
# 6   382043  Samsung           77
# 7   302948  Samsung          143
# 8   100132       LG           60
# 9   312394      ZTE           19
#    purchase_id  item_id  price
# 0          101   417283  13900
# 1          101   849734   5330
# 2          101   132223  38200
# 3          112   573943  49990
# 4          121    19475   9890
# 5          145  3294095  33000
# 6          145   382043  67500
# 7          145   302948  34500
# 8          145   103845  89900
# 9          221   100132  11400

# %%
merged = items_df.merge(purchase_df, how='inner', on='item_id')
merged
# Out:
#    item_id   vendor  stock_count  purchase_id  price
# 0   417283  Samsung           54          101  13900
# 1   849734       LG           33          101   5330
# 2   132223    Apple          122          101  38200
# 3   573943    Apple           18          112  49990
# 4    19475       LG          102          121   9890
# 5  3294095    Apple           43          145  33000
# 6   382043  Samsung           77          145  67500
# 7   302948  Samsung          143          145  34500
# 8   100132       LG           60          221  11400

# %%
income1 = merged ['price'] * merged ['stock_count']
income = income1.sum()
income
# Out:
# 19729490.0

# %% [markdown]
# ## Итоговые задания к модулю

# %%
import re 
def get_year_release(arg):
    #находим все слова по шаблону "(DDDD)"
    candidates = re.findall(r'\(\d{4}\)', arg) 
    # проверяем число вхождений
    if len(candidates) > 0:
        #если число вхождений больше 0,
	#очищаем строку от знаков "(" и ")"
        year = candidates[0].replace('(', '')
        year = year.replace(')', '')
        return int(year)
    else:
        #если год не указан, возвращаем None
        return None

# %%
#rating = pd.read_csv ('data/ratings_movies.csv')
rating.head()
# Out:
#    Unnamed: 0  userId  movieId  rating                 date  \
# 0           0       1        1     4.0  2000-07-30 18:45:03
# 1           1       1        3     4.0  2000-07-30 18:20:47
# 2           2       1        6     4.0  2000-07-30 18:37:04
# 3           3       1       47     5.0  2000-07-30 19:03:35
# 4           4       1       50     5.0  2000-07-30 18:48:51
#
#                          title                                       genres
# 0             Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1      Grumpier Old Men (1995)                               Comedy|Romance
# 2                  Heat (1995)                        Action|Crime|Thriller
# 3  Seven (a.k.a. Se7en) (1995)                             Mystery|Thriller
# 4   Usual Suspects, The (1995)                       Crime|Mystery|Thriller

# %%
#rating ['year_release'] = rating ['title'].apply (get_year_release)
mask = rating ['year_release'] == 1999
rati = rating[mask].pivot_table (
    values = "rating",
    index = 'title', 
    columns='year_release',
    aggfunc='mean',
    fill_value=0
)
rati.sort_values (by=1999)
# Out:
# year_release                                1999.0
# title
# Bloodsport: The Dark Kumite (1999)             0.5
# Simon Sez (1999)                               1.0
# Chill Factor (1999)                            1.0
# Source, The (1999)                             1.0
# Trippin' (1999)                                1.0
# ...                                            ...
# Trailer Park Boys (1999)                       5.0
# Larry David: Curb Your Enthusiasm (1999)       5.0
# Sun Alley (Sonnenallee) (1999)                 5.0
# George Carlin: You Are All Diseased (1999)     5.0
# Five Senses, The (1999)                        5.0
#
# [261 rows x 1 columns]

# %%
mask = rating ['year_release'] == 2010
rati = rating[mask].pivot_table (
    values = "rating",
    index = 'genres', 
    columns='year_release',
    aggfunc='mean',
    fill_value=0
)
rati.sort_values (by=2010)
# Out:
# year_release                         2010.0
# genres
# Action|Sci-Fi                      1.000000
# Action|Adventure|Horror            1.500000
# Action|Drama|Fantasy               1.500000
# Crime|Romance                      1.500000
# Adventure|Comedy|Fantasy           1.833333
# ...                                     ...
# Crime                              4.750000
# Comedy|Musical                     5.000000
# Animation|Drama|Fantasy|Mystery    5.000000
# Adventure|Children|Comedy|Mystery  5.000000
# Animation|Children|Mystery         5.000000
#
# [119 rows x 1 columns]

# %%
rating.groupby('userId')['genres'].nunique().sort_values(ascending=False)# сгруппировано по юсеру количество жанров
# Out:
# userId
# 599    524
# 414    482
# 448    403
# 380    399
# 474    395
#       ...
# 578     15
# 12      15
# 85      13
# 214     13
# 245     13
# Name: genres, Length: 610, dtype: int64

# %%
rating.groupby('userId')['rating'].agg(
    ['count', 'mean']
).sort_values(by=['count', 'mean'], ascending=[True, False])
# Out:
#         count      mean
# userId
# 53         20  5.000000
# 595        20  4.200000
# 189        20  4.100000
# 569        20  4.000000
# 278        20  3.875000
# ...       ...       ...
# 274      1346  3.235884
# 448      1864  2.847371
# 474      2108  3.398956
# 599      2478  2.642050
# 414      2698  3.391957
#
# [610 rows x 2 columns]

# %%
mask1 = rating ['year_release'] == 2018
#mask2 = rating ['rating'].count > 10
rating [mask1].groupby ('genres')['rating'].agg(
    ['count', 'mean']
).sort_values(by=['count', 'mean'], ascending=[False, False])
# Out:
#                                         count      mean
# genres
# Action|Adventure|Sci-Fi                    14  3.928571
# Action|Comedy|Sci-Fi                       12  3.875000
# Comedy                                      8  3.312500
# Action|Adventure|Children|Sci-Fi            5  3.900000
# Animation|Comedy                            5  3.500000
# Action|Adventure|Animation|Children         4  3.000000
# Drama|Horror|Thriller                       4  2.750000
# Action|Adventure|Fantasy                    4  2.500000
# Adventure|Mystery|Sci-Fi|Thriller           3  3.833333
# Action|Adventure|Comedy|Fantasy|Sci-Fi      3  3.666667
# Documentary                                 2  4.000000
# Action|Adventure|Thriller                   2  3.750000
# Action|Adventure|Drama|Sci-Fi|Thriller      2  3.250000
# Comedy|Drama                                2  3.250000
# Action|Fantasy|Sci-Fi                       2  2.750000
# Horror|Mystery|Sci-Fi|Thriller              2  2.250000
# ...

# %%
#rating ['date'] = pd.to_datetime(rating ['date'])
#rating ['year_rating'] = rating ['date'].dt.year 
#dates_df['year'] = dates_df['date'].dt.year
rating.pivot_table (
    values = "rating",
    index = 'year_rating', 
    columns='genres',
    aggfunc='mean',
    fill_value=0
)
# Out:
# genres       (no genres listed)    Action  Action|Adventure  \
# year_rating
# 1996                   0.000000  2.730769          3.454545
# 1997                   0.000000  3.538462          4.150000
# 1998                   0.000000  0.000000          4.200000
# 1999                   0.000000  0.000000          4.000000
# 2000                   0.000000  2.588235          3.738462
# 2001                   0.000000  3.000000          3.500000
# 2002                   0.000000  2.750000          4.304348
# 2003                   0.000000  3.833333          3.277778
# 2004                   0.000000  2.700000          4.136364
# 2005                   0.000000  3.357143          3.413043
# 2006                   0.000000  2.166667          4.090909
# 2007                   0.000000  2.583333          3.666667
# 2008                   0.000000  3.000000          3.656250
# 2009                   0.000000  0.000000          3.714286
# ...

# %%
#products = pd.read_csv ('data/products.csv', sep=';')
#orders = pd.read_csv ('data/orders.csv', sep=';')
orders.tail ()
# Out:
#           Дата создания  Order ID  ID Покупателя  \
# 13  08.11.2019 08:36:21         2              7
# 14  08.11.2019 08:36:20         1              5
# 15  08.11.2019 08:36:20         1              5
# 16  08.11.2019 08:36:20         1              5
# 17  01.01.2001 00:00:00         0              1
#
#                              Статус Оплачен Отменен Отгружен  ID товара  \
# 13                         Выполнен      Да     Нет       Да         47
# 14  Оплачен, формируется к отправке      Да     Нет      Нет         71
# 15  Оплачен, формируется к отправке      Да     Нет      Нет         86
# 16  Оплачен, формируется к отправке      Да     Нет      Нет         51
# 17  Оплачен, формируется к отправке      Да     Нет      Нет        666
#
#     Количество
# 13           1
# 14           1
# 15           1
# 16           1
# 17           1

# %%
products.head(10)
# Out:
#    Product_ID                      Name  Price CURRENCY
# 0          47      Шатны Полосатый рейс   2999      RUR
# 1          51  Платье Аленький цветочек   4999      RUR
# 2          53    Штаны Цветочная Поляна   4999      RUR
# 3          71       Платье Ночная Жизнь   7999      RUR
# 4          74  Платье Ночная Жизнь XXXL   8999      RUR
# 5          86        Носки Простые, муж     45      RUR
# 6          91        Носки Честные, муж     50      RUR
# 7         103     Носки Подарочные, муж    199      RUR
# 8         104     Носки Подарочные, жен    249      RUR
# 9         124      Носки беговые Camino    999      RUR

# %%
orders_products = orders.merge(products, how='inner', right_on='Product_ID', left_on='ID товара')
mask = orders_products ['Оплачен'] == 'Да'
orders_products ['profit'] = orders_products ['Количество'] * orders_products ['Price']
orders_products.pivot_table (
    values = "profit",
    index = 'ID Покупателя', 
    columns='Order ID',
    aggfunc='sum',
    fill_value=0
)
# Out:
# Order ID           1      2     3   4    5     6     7     8    9
# ID Покупателя
# 1                  0      0     0   0    0  2240     0     0    0
# 5              13043      0     0   0  999     0     0     0    0
# 7                  0  17096     0   0    0     0     0     0    0
# 8                  0      0  1344   0    0     0  1743     0    0
# 9                  0      0     0  50    0     0     0  6990    0
# 10                 0      0     0   0    0     0     0     0  995
