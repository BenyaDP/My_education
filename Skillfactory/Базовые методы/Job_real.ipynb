# %%
import pandas as pd
tabl = pd.read_excel ('111.xls')
tabl.head(20)
# Out:
#                                   Unnamed: 0  Unnamed: 1  \
# 0          Себестоимость товаров организаций         NaN
# 1                                        NaN         NaN
# 2                                 Параметры:         NaN
# 3                                        NaN         NaN
# 4                                        NaN         NaN
# 5                                     Отбор:         NaN
# 6                                        NaN         NaN
# 7                                Организация         NaN
# 8                                      Склад         NaN
# 9                            ООО "НТЦ "ЗЭРС"         NaN
# 10  Склад оборудования г. Нефтекамск (Серии)         NaN
# 11  Склад оборудования г. Нефтекамск (Серии)         NaN
# 12  Склад оборудования г. Нефтекамск (Серии)         NaN
# 13     Склад оборудования г. Бузулук (Серии)         NaN
# 14      Склад оборудования г. Рязань (Серии)         NaN
# ...

# %%
tabl.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16'],
#       dtype='object')

# %%
tabl = tabl.drop ([8,9], axis=0)
tabl
# Out:
#                                           Склад  \
# 10     Склад оборудования г. Нефтекамск (Серии)
# 11     Склад оборудования г. Нефтекамск (Серии)
# 12     Склад оборудования г. Нефтекамск (Серии)
# 13        Склад оборудования г. Бузулук (Серии)
# 14         Склад оборудования г. Рязань (Серии)
# ...                                         ...
# 10987                 Газпромнефть Ямал  серии
# 10988                 Газпромнефть Ямал  серии
# 10989      Склад оборудования г. Рязань (Серии)
# 10990      Склад оборудования г. Рязань (Серии)
# 10991                                     Итого
#
#                                             Номенклатура  \
# 10      НЕ ИСПОЛЬЗОВАТЬ!!! ПП.3-83/3-102.000, 00-0001...
# 11      НЕ ИСПОЛЬЗОВАТЬ!!! ПП.3-83/3-102.000, 00-0001...
# 12      НЕ ИСПОЛЬЗОВАТЬ!!! ПП.3-83/3-102.000, 00-0001...
# 13      НЕ ИСПОЛЬЗОВАТЬ!!! ПП.3-83/3-102.000, 00-0001...
# 14     !!!НЕ ИСПОЛЬЗОВАТЬ Кольцо 024-030-36-2-4, 00-0...
# ...

# %%
tabl = tabl.rename({'Unnamed: 10': 'Себестоимость'}, axis=1)

# %%
#tabl2 = pd.read_excel ('123.xls')
tabl2.head(15)
# Out:
#                       Unnamed: 0  Unnamed: 1                       Unnamed: 2  \
# 0                     Параметры:         NaN         Контрагент: НТЦ ЗЭРС ООО
# 1                            NaN         NaN     Организация: ООО "НПО "ЗЭРС"
# 2                            NaN         NaN  Период: 01.10.2021 - 30.09.2022
# 3                            NaN         NaN                              NaN
# 4                    Организация         NaN                              NaN
# 5                     Контрагент         NaN                              NaN
# 6                   Номенклатура         NaN                              NaN
# 7                ООО "НПО "ЗЭРС"         NaN                              NaN
# 8   Абрамов Александр Михайлович         NaN                              NaN
# 9        Лом обрезь и детали ч/м         NaN                              NaN
# 10         АВТОСПЕЦМАРКЕТ ПО ООО         NaN                              NaN
# ...

# %%
tabl2 = tabl2.drop ([4], axis=0)
tabl2
# Out:
#                         Наименование             Серия  Себестоимость  \
# 8       Абрамов Александр Михайлович         Заявление        6689.52
# 9            Лом обрезь и детали ч/м               NaN        6689.52
# 10             АВТОСПЕЦМАРКЕТ ПО ООО              Счет     2080773.13
# 11         Винт  М10*1*6 45Н DIN 916               NaN         918540
# 12             Винт  М10*1*6 DIN 916               NaN         348975
# ...                              ...               ...            ...
# 15084       Шеина Наталья Васильевна  Заявление на лом        2966.27
# 15085        Лом обрезь и детали ч/м               NaN        2966.27
# 15086  Якунин Александр Владимирович  Заявление на лом        7967.35
# 15087        Лом обрезь и детали ч/м               NaN        7967.35
# 15088                          Итого               NaN  1136803580.86
#
#       Количество
# 8            325
# 9            325
# 10        775800
# 11        291600
# 12        259200
# ...

# %%
tabl2 = tabl2.rename({'Unnamed: 0': 'Наименование','Unnamed: 5': 'Серия', 'Unnamed: 8': 'Себестоимость', 'Unnamed: 9': 'Количество' }, axis=1)

# %%
#tabl3 = pd.merge(tabl, tabl2, how='left', left_on=['Номенклатура', 'Серия'], right_on=['Наименование', 'Серия'])
tabl3
# Out:
#                                           Склад  \
# 0      Склад оборудования г. Нефтекамск (Серии)
# 1      Склад оборудования г. Нефтекамск (Серии)
# 2      Склад оборудования г. Нефтекамск (Серии)
# 3         Склад оборудования г. Бузулук (Серии)
# 4          Склад оборудования г. Рязань (Серии)
# ...                                         ...
# 10977                 Газпромнефть Ямал  серии
# 10978                 Газпромнефть Ямал  серии
# 10979      Склад оборудования г. Рязань (Серии)
# 10980      Склад оборудования г. Рязань (Серии)
# 10981                                     Итого
#
#                                             Номенклатура  \
# 0       НЕ ИСПОЛЬЗОВАТЬ!!! ПП.3-83/3-102.000, 00-0001...
# 1       НЕ ИСПОЛЬЗОВАТЬ!!! ПП.3-83/3-102.000, 00-0001...
# 2       НЕ ИСПОЛЬЗОВАТЬ!!! ПП.3-83/3-102.000, 00-0001...
# 3       НЕ ИСПОЛЬЗОВАТЬ!!! ПП.3-83/3-102.000, 00-0001...
# 4      !!!НЕ ИСПОЛЬЗОВАТЬ Кольцо 024-030-36-2-4, 00-0...
# ...

# %%
tabl3.to_excel("output.xlsx")

# %%
tabl['Количество'].astype (int)
tabl.info ()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [70], line 1
# ----> 1 tabl['Количество'].astype (int)
#       2 tabl.info ()
#
# File c:\Users\БелоусовДП\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# ...

# %%
tabl['Номенклатура'] = tabl['Номенклатура'].apply(lambda x: x [:len(x)-16])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [68], line 1
# ----> 1 tabl['Номенклатура'] = tabl['Номенклатура'].apply(lambda x: x [:len(x)-16])
#
# File c:\Users\БелоусовДП\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
#    4667 ) -> DataFrame | Series:
#    4668     """
#    4669     Invoke function on values of Series.
#    4670
#    (...)
#    4769     dtype: float64
#    4770     """
# -> 4771     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File c:\Users\БелоусовДП\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\apply.py:1105, in SeriesApply.apply(self)
#    1102     return self.apply_str()
# ...
